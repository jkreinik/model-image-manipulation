# %%
import cv2
import numpy as np
import PIL

# %%
from tkinter import *
from PIL import ImageTk,Image

# %%
canvas = Canvas(width = 200, height = 200, bg = 'blue')
canvas.pack(expand = YES, fill = BOTH)

image = ImageTk.PhotoImage(file = "stool1.jpg")
canvas.create_image(10, 10, image = image, anchor = NW)

#mainloop()
# Out:
# Exception ignored in: <bound method PhotoImage.__del__ of <PIL.ImageTk.PhotoImage object at 0x1195a9b38>>
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.6/site-packages/PIL/ImageTk.py", line 130, in __del__
#     name = self.__photo.name
# AttributeError: 'PhotoImage' object has no attribute '_PhotoImage__photo'
# Exception ignored in: <bound method PhotoImage.__del__ of <PIL.ImageTk.PhotoImage object at 0x12aef0400>>
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.6/site-packages/PIL/ImageTk.py", line 130, in __del__
#     name = self.__photo.name
# AttributeError: 'PhotoImage' object has no attribute '_PhotoImage__photo'
# 1

# %%
backgroundImage=ImageTk.PhotoImage(file = "orange_sunset.jpg")

# %%
from PIL import Image
img = Image.open('stool1.jpg', 'r')
img_w, img_h = img.size
background = Image.open('orange_sunset.jpg','r')
bg_w, bg_h = background.size
offset = ((bg_w - img_w) // 2, (bg_h - img_h) // 2)
background.paste(img, offset)
background.save('out.png')

# %%
test_image = "orange_sunset.jpg"
original = Image.open(test_image)
stool1 = "stool1.jpg"
original_stool = Image.open(stool1)
stoolw,stoolh = original_stool.size
print(stoolw,stoolh)

# original.show()

width, height = original.size   # Get dimensions
print(width, height)
left = width/4
top = height/4
right = 3 * width/4
bottom = 3 * height/4
cropped_example = original.crop((left, top, right, bottom))

# cropped_example.show()
# Out:
# 1262 1100
# 960 720

# %%
stool1 = Image.open('white_stool.jpg', 'r')
background = Image.open('orange_sunset.jpg', 'r')

PIL.Image.blend(stool1,background,.5)
# Out:
# <PIL.Image.Image image mode=RGB size=960x720 at 0x12AE6EE10>

# %%
background_living_room = Image.open('living_room.jpg', 'r')
PIL.Image.blend(stool1,background_living_room,.25)
# Out:
# <PIL.Image.Image image mode=RGB size=960x720 at 0x12AE5E320>
